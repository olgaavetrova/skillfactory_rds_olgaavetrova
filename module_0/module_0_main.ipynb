# %%
21/42
# Out:
# 0.5

# %%
values = [-7, -7, 7, 7]
std = 42

def count_std():
    mean = sum(values)/len(values)
    std = (sum([(value-mean)**2 for value in values])/len(values))**0.5
    return std

def normalize(value):
    result = value/std
    return result 

print(normalize(21))
# Out:
# 0.5

# %%
rabbits = 0

def count_rabbits(spotted):
    global rabbits
    rabbits += spotted

    
count_rabbits(3)
count_rabbits(5)
print(rabbits)
# Out:
# 8

# %%
def send_package(data=""):
# Out:
#   File "<ipython-input-8-32c60be836ab>", line 1
#     def send_package(data=""):
#                               ^
# SyntaxError: unexpected EOF while parsing

# %%
def normalize(numbers, mean=0, std=1):
    func=[]  
    for num in numbers:
       func.append((num - mean)/std)
    return func
normalize([10, 20], mean=15)
# Out:
# [-5.0, 5.0]

# %%
def sum_args (*arg):
    sum=0
    for num in arg:
        sum += num
    return sum
sum_args(10, 15, -4)
# Out:
# 21

# %%
def show_keys(**kwargs):
    print(' '.join(kwargs.keys()))

show_keys(verbose=True, mode='constant')
# Out:
# verbose mode

# %%
def count_letters(sentence, average = False):
        sum = 0
        sum_word = 0
        #if average == False:
        for letter in sentence:
            if letter == ' ':
                continue
            else:
                sum += 1
        return sum
count_letters("Beep boop") # => 8
# Out:
# 8

# %%
def count_letters(sentence, average = False):
        sum = 0
        sum_word = 1
        if average == False:
            for letter in sentence:
                if letter == ' ':
                    continue
                else:
                    sum += 1
            return sum
        else:
            for letter in sentence:
                if letter == ' ':
                    sum_word += 1
                else:
                    sum += 1
            return (sum/sum_word)          
count_letters("Beep boop", average=True) # => 4
# Out:
# 4.0

# %%
words = ["sofa", "suitcase", "valise", "picture", "basket", "carton", "doggie"]
list(map(lambda w: sorted(w)[0], words))[5]
# Out:
# 'a'

# %%
def always(n):
    return n
five = always(5)
five() # должно вернуть 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-6e0aa3801ad9> in <module>
#       2     return n
#       3 five = always(5)
# ----> 4 five() # должно вернуть 5
#
# TypeError: 'int' object is not callable

# %%
def always(n):
    def func():
        return n
    return func
five = always(5)
five() # должно вернуть 5
# Out:
# 5

# %%
Num = input("Enter a number: ")
ost =Num
%2
if ost > 0:
    print("You picked an odd number.")
else:
    print("You picked an even number.")

# %%
count = 0                            # счетчик попыток
number = np.random.randint(1,101)    # загадали число
print ("Загадано число от 1 до 100")

while True:                        # бесконечный цикл
    predict = int(input())         # предполагаемое число
    count += 1                     # плюсуем попытку
    if number == predict: break    # выход из цикла, если угадали
    elif number > predict: print (f"Угадываемое число больше {predict} ")
    elif number < predict: print (f"Угадываемое число меньше {predict} ")
        
print (f"Вы угадали число {number} за {count} попыток.")

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-808de8f03846> in <module>
#       1 count = 0                            # счетчик попыток
# ----> 2 number = np.random.randint(1,101)    # загадали число
#       3 print ("Загадано число от 1 до 100")
#       4
#       5 while True:                        # бесконечный цикл
#
# NameError: name 'np' is not defined

# %%
import numpy as np

# %%
count = 0                            # счетчик попыток
number = np.random.randint(1,101)    # загадали число
print ("Загадано число от 1 до 100")

while True:                        # бесконечный цикл
    predict = int(input())         # предполагаемое число
    count += 1                     # плюсуем попытку
    if number == predict: break    # выход из цикла, если угадали
    elif number > predict: print (f"Угадываемое число больше {predict} ")
    elif number < predict: print (f"Угадываемое число меньше {predict} ")
        
print (f"Вы угадали число {number} за {count} попыток.")
# Out:
# Загадано число от 1 до 100
# 99
# Угадываемое число меньше 99
# 5
# Угадываемое число больше 5
# 40
# Угадываемое число больше 40
# 70
# Угадываемое число больше 70
# 80
# Угадываемое число больше 80
# 86
# Угадываемое число больше 86
# 99
# Угадываемое число меньше 99
# 98
# Угадываемое число меньше 98
# 95
# Угадываемое число больше 95
# 96
# Вы угадали число 96 за 10 попыток.

# %%
number = np.random.randint(1,101)    # загадали число
print ("Загадано число от 1 до 100")
for count in range(1,101):         # более компактный вариант счетчика
    if number == count: break    # выход из цикла, если угадали      
print (f"Вы угадали число {number} за {count} попыток.")
# Out:
# Загадано число от 1 до 100
# Вы угадали число 17 за 17 попыток.

# %%
import numpy as np

# %%
def game_core_v2(number):
    '''Сначала устанавливаем любое random число, а потом уменьшаем или увеличиваем его в зависимости от того, больше оно или меньше нужного.
       Функция принимает загаданное число и возвращает число попыток'''
    count = 1
    predict = np.random.randint(1,101)
    print (predict)
    while number != predict:
        count+=1
        if number > predict: 
            predict += 1
        elif number < predict: 
            predict -= 1
    return(count) # выход из цикла, если угадали

def score_game(game_core):
    '''Запускаем игру 1000 раз, чтобы узнать, как быстро игра угадывает число'''
    count_ls = []
    np.random.seed(1)  # фиксируем RANDOM SEED, чтобы ваш эксперимент был воспроизводим!
    random_array = np.random.randint(1,101, size=(5))
    print(random_array)
    for number in random_array:
        count_ls.append(game_core(number))
    score = int(np.mean(count_ls))
    print(f"Ваш алгоритм угадывает число в среднем за {score} попыток")
    return(score)

# %%
score_game(game_core_v2)
# Out:
# [38 13 73 10 76]
# 6
# 80
# 65
# 17
# 2
# Ваш алгоритм угадывает число в среднем за 38 попыток
# 38

# %%
def game_core_v3(number):
    '''Сначала устанавливаем любое random число, а потом уменьшаем или увеличиваем его в зависимости от того, больше оно или меньше нужного.
       Функция принимает загаданное число и возвращает число попыток'''
    count = 1
    predict = np.random.randint(1,101)
    print('predict', predict)
    left = 0
    right = predict
    while number != predict:
        count+=1
        if number > predict: 
            left = predict+1
            predict = predict+10
            right = predict
        elif number < predict:
            right = predict - 1
            predict =  int((left + right)/2)
    return(count) # выход из цикла, если угадали

def score_game(game_core):
    '''Запускаем игру 1000 раз, чтобы узнать, как быстро игра угадывает число'''
    count_ls = []
    np.random.seed(1)  # фиксируем RANDOM SEED, чтобы ваш эксперимент был воспроизводим!
    random_array = np.random.randint(1,101, size=(1000))
    print (random_array) 
    for number in random_array:
        count_ls.append(game_core(number))
    score = int(np.mean(count_ls))
    print(f"Ваш алгоритм угадывает число в среднем за {score} попыток")
    return(score)

# %%
score_game(game_core_v3)
# Out:
# [ 38  13  73  10  76   6  80  65  17   2  77  72   7  26  51  21  19  85
#   12  29  30  15  51  69  88  88  95  97  87  14  10   8  64  62  23  58
#    2   1  61  82   9  89  14  48  73  31  72   4  71  22  50  58   4  69
#   25  44  77  27  53  81  42  83  16  65  69  26  99  88   8  27  26  23
#   10  68  24  28  38  58  84  39   9  33  35  11  24  16  88  26  72  93
#   75  63  47  33  89  24  56  66  78   4   1  78   7  53  86  71   3  77
#   92  22  76   8  78  73  76  77  44  21  31  37   8  46  69  58  83  97
#   14  11  24  82   8  25  75  93  21  33  13  66  95  61  25  83  98   3
#   93  99  11  55  97  83  87  71  67  72  49  55  16   6  18  43  21  49
#   23  14  98  54  85  11  97  56  62  57  90  22  97  84  26  15  14  85
#   44   7  78  57  60  16  25  10  67  72  54  70  37  22  41  78  92  50
#   48  78  41  79  46  88  17  29  46  68  67  79  47   1  30  64  76  36
#   54  94  34   3  85  84  49  55  33  29  56  83  32  29  95  75   9 100
#   33   9  85  78  51  80  42  65  84  25  21  45  16  31  92  15  20  27
#   87   8 100  54  48  61  35  33  20  68  25  84  95  39  48   6  80  64
#   88  33  43  75  67  89  99  31  18  69  65  61  79  18  40  36  82  29
#   23  39  42  75  78  71  26  49  51  63  45  55   1  87  17  20  10  93
#   52  11  69  24  15  64  22  47   4  57  89  81  47  55  80  72  15  78
#   16  26  54  85  59  86  30  45  38  23  92  55  77  13  60  27  77  72
#   88  40  44  77  39  92  70  99  34  44  27  57  70  74  53  90  28  44
#    2  83  95  97  27  85  31  65  23  99  53   4  71  13  40  84  49  62
#   71  14  37  24  23  67  93  96  54  10  42  58  89  94  77  83  12  37
#   17  31  85  58  36  42  82   3  86  94  37  47  81  28  73  29   3 100
#   14  42  37  41  19  98  39  64  47  90   3  99  29  79  76  59  43  27
#   22  59  17  93  38  12  23   7  97  15  88  76  36  64  33  92  50   1
#   23  98  71  37  19  28  29  53  95  51  47   8  86  17  30  12  62  15
#   31   9  41  49  31  24  67  93  65  13  18  34  11  29  76   6  82   6
#   43  87  53  58  57  79  88  82  11  73  49  20  13  26  78  17   5  89
#   28  51  69   4  59  13   3  77  97  97  62  16  75  13  19  31  60   6
#   17  96  97  61  44  32 100  45  25  63  80  22  20  78  34   5  40  68
#   35  35  43  79  83  39  49  82   6  92   9  41  70   6   8  79  38  79
#   34  28  52  78  31  44  47  10  68   4  68  55  98  64 100  81  29  38
#   65  38  94  19  79  71  93  53  11  33  47  64  94  19  37  30  40  29
#   55  30  56  91  28  61  13  18  72  92   8  84  57  52  33  77  63  52
#   97  31  23   6  92  96  23  77  23  19  94  30  19  53  32  50  99  84
#   94  46  52  87  16  72  49  29  84  28  44  20  80  71  89  87  12  66
#   94  16  52  99  87  46  64  43  23  83  41  45  17  18  89   1  98  83
#   72  15  37  27  33   2  49  89  23  35  95  22  69  68  49  19  98  12
#   12  53  77  69  46  65  90  41   8   8  34  59   8  35   5   6  62  51
#   77  46  97  22  93  72  93  26  98   2  14  39  86  28  39  85  34   2
#   32  39  29  76 100  32  52  67  68  33  75  33  98   6   1  38  73  44
#   25  17  97  97  42  25  22  28  47  36  63  69  63  33  46  89  43  58
#   26  33  34   7  66  52  32   8  14   4  29  16  30  67  62  84  97  59
#   83  35  31  58  97  50  47  84  42  21  41  51   5  10   1  91  22  75
#   22  34  39  38  44  34  96  42  72  70  71  24  87  40  32  38  39  57
#   88  29  37  67  11  85   1  17  31   4  79  60  54  70  50  75  47  28
#   34  73  69  40  33  98   8  34  63  15  78  44  62  86  37  13  54  27
#   83 100  13 100  26   2  42  56  56  65  16  93  41  61  71  50  51  33
#   91  21  53  39  66  81  58  53  90  20  95  65  43  48  22  98   2  90
#   39  13  19  78  78  89  91  84  40  99  16  38  97  37  99   2  33  31
#    8  51  51  33  44  42  70   2  98  52  31  83  50  82  83  96  72  22
#   19  47  45  92  10   5  78  64  24  96  60  65  83  32   2  85  79  69
#   55  26  84  28  57  93   9  56  77  47  50  12   9  62  75  24  89  90
#   83  83   6  43  47  22  52  74  43  14  19  24  46  96  53  34  55  15
#   58  62  41  73  66  23   3  87   2  73  52  72  88  78  63  49   1  43
#   40   4  58  44  54  44  75  99  98  76]
# predict 60
# predict 67
# predict 75
# predict 92
# predict 6
# predict 27
# predict 68
# predict 32
# predict 12
# predict 4
# predict 55
# predict 2
# predict 14
# predict 60
# predict 57
# predict 82
# predict 9
# predict 39
# predict 5
# predict 71
# predict 77
# predict 74
# predict 6
# predict 80
# predict 85
# predict 60
# predict 32
# predict 91
# predict 8
# predict 67
# predict 33
# predict 47
# predict 76
# predict 83
# predict 45
# predict 65
# predict 38
# predict 48
# predict 74
# predict 91
# predict 85
# predict 16
# predict 66
# predict 53
# predict 70
# predict 67
# predict 90
# predict 29
# predict 20
# predict 18
# predict 6
# predict 80
# predict 11
# predict 30
# predict 18
# predict 82
# predict 47
# predict 8
# predict 18
# predict 87
# predict 62
# predict 65
# predict 8
# predict 30
# predict 56
# predict 29
# predict 100
# predict 44
# predict 99
# predict 56
# predict 6
# predict 51
# predict 93
# predict 64
# predict 53
# predict 35
# predict 99
# predict 84
# predict 78
# predict 38
# predict 90
# predict 55
# predict 5
# predict 44
# predict 12
# predict 30
# predict 77
# predict 90
# predict 33
# predict 51
# predict 52
# predict 43
# predict 24
# predict 90
# predict 44
# predict 89
# predict 96
# predict 29
# predict 65
# predict 87
# predict 59
# predict 89
# predict 52
# predict 23
# predict 11
# predict 32
# predict 10
# predict 7
# predict 31
# predict 68
# predict 19
# predict 13
# predict 74
# predict 75
# predict 92
# predict 66
# predict 86
# predict 54
# predict 43
# predict 7
# predict 10
# predict 37
# predict 88
# predict 60
# predict 9
# predict 54
# predict 88
# predict 19
# predict 22
# predict 68
# predict 15
# predict 21
# predict 86
# predict 10
# predict 43
# predict 67
# predict 21
# predict 17
# predict 59
# predict 78
# predict 43
# predict 36
# predict 76
# predict 29
# predict 86
# predict 35
# predict 45
# predict 93
# predict 83
# predict 9
# predict 31
# predict 65
# predict 78
# predict 19
# predict 39
# predict 12
# predict 57
# predict 53
# predict 84
# predict 77
# predict 69
# predict 26
# predict 100
# predict 70
# predict 32
# predict 60
# predict 63
# predict 30
# predict 67
# predict 33
# predict 72
# predict 61
# predict 94
# predict 73
# predict 28
# predict 98
# predict 94
# predict 69
# predict 39
# predict 61
# predict 98
# predict 10
# predict 68
# predict 79
# predict 64
# predict 21
# predict 36
# predict 56
# predict 29
# predict 46
# predict 93
# predict 57
# predict 52
# predict 5
# predict 80
# predict 76
# predict 32
# predict 77
# predict 53
# predict 39
# predict 84
# predict 81
# predict 75
# predict 71
# predict 27
# predict 58
# predict 31
# predict 100
# predict 65
# predict 39
# predict 19
# predict 96
# predict 42
# predict 96
# predict 58
# predict 49
# predict 43
# predict 53
# predict 23
# predict 65
# predict 71
# predict 62
# predict 61
# predict 97
# predict 28
# predict 1
# predict 27
# predict 51
# predict 21
# predict 27
# predict 66
# predict 78
# predict 19
# predict 61
# predict 83
# predict 60
# predict 63
# predict 39
# predict 24
# predict 69
# predict 70
# predict 62
# predict 88
# predict 67
# predict 20
# predict 37
# predict 18
# predict 22
# predict 78
# predict 27
# predict 33
# predict 9
# predict 9
# predict 21
# predict 69
# predict 83
# predict 55
# predict 86
# predict 94
# predict 75
# predict 90
# predict 24
# predict 95
# predict 91
# predict 14
# predict 12
# predict 43
# predict 11
# predict 89
# predict 25
# predict 48
# predict 69
# predict 44
# predict 92
# predict 14
# predict 7
# predict 3
# predict 68
# predict 94
# predict 5
# predict 29
# predict 36
# predict 83
# predict 78
# predict 47
# predict 79
# predict 7
# predict 92
# predict 81
# predict 21
# predict 24
# predict 64
# predict 100
# predict 72
# predict 7
# predict 22
# predict 65
# predict 51
# predict 91
# predict 10
# predict 93
# predict 68
# predict 86
# predict 34
# predict 72
# predict 9
# predict 52
# predict 34
# predict 100
# predict 62
# predict 8
# predict 60
# predict 42
# predict 28
# predict 52
# predict 41
# predict 72
# predict 46
# predict 95
# predict 10
# predict 89
# predict 47
# predict 59
# predict 22
# predict 55
# predict 1
# predict 20
# predict 20
# predict 86
# predict 28
# predict 98
# predict 22
# predict 95
# predict 19
# predict 68
# predict 36
# predict 96
# predict 30
# predict 23
# predict 57
# predict 11
# predict 43
# predict 73
# predict 32
# predict 13
# predict 83
# predict 8
# predict 88
# predict 9
# predict 62
# predict 24
# predict 35
# predict 95
# predict 4
# predict 56
# predict 69
# predict 16
# predict 25
# predict 95
# predict 63
# predict 27
# predict 99
# predict 48
# predict 88
# predict 36
# predict 17
# predict 88
# predict 91
# predict 79
# predict 88
# predict 58
# predict 25
# predict 56
# predict 50
# predict 53
# predict 25
# predict 16
# predict 68
# predict 74
# predict 47
# predict 21
# predict 67
# predict 95
# predict 13
# predict 26
# predict 1
# predict 98
# predict 99
# predict 78
# predict 12
# predict 91
# predict 25
# predict 55
# predict 48
# predict 78
# predict 41
# predict 60
# predict 96
# predict 80
# predict 90
# predict 32
# predict 57
# predict 34
# predict 39
# predict 93
# predict 21
# predict 15
# predict 10
# predict 68
# predict 82
# predict 80
# predict 4
# predict 48
# predict 71
# predict 43
# predict 6
# predict 21
# predict 58
# predict 60
# predict 55
# predict 78
# predict 25
# predict 59
# predict 80
# predict 37
# predict 81
# predict 59
# predict 52
# predict 64
# predict 74
# predict 84
# predict 89
# predict 83
# predict 56
# predict 79
# predict 71
# predict 28
# predict 24
# predict 54
# predict 70
# predict 69
# predict 24
# predict 47
# predict 40
# predict 67
# predict 78
# predict 27
# predict 25
# predict 18
# predict 88
# predict 2
# predict 46
# predict 59
# predict 22
# predict 18
# predict 57
# predict 34
# predict 44
# predict 76
# predict 99
# predict 3
# predict 97
# predict 91
# predict 84
# predict 27
# predict 27
# predict 53
# predict 56
# predict 8
# predict 63
# predict 100
# predict 32
# predict 80
# predict 93
# predict 77
# predict 47
# predict 88
# predict 71
# predict 70
# predict 56
# predict 93
# predict 99
# predict 88
# predict 86
# predict 75
# predict 16
# predict 15
# predict 57
# predict 88
# predict 2
# predict 85
# predict 76
# predict 77
# predict 91
# predict 19
# predict 63
# predict 46
# predict 66
# predict 53
# predict 29
# predict 88
# predict 39
# predict 21
# predict 98
# predict 52
# predict 60
# predict 95
# predict 65
# predict 15
# predict 98
# predict 53
# predict 45
# predict 17
# predict 65
# predict 31
# predict 83
# predict 11
# predict 46
# predict 89
# predict 79
# predict 100
# predict 60
# predict 98
# predict 43
# predict 65
# predict 6
# predict 91
# predict 77
# predict 56
# predict 43
# predict 21
# predict 89
# predict 69
# predict 19
# predict 93
# predict 50
# predict 84
# predict 16
# predict 18
# predict 62
# predict 8
# predict 65
# predict 56
# predict 3
# predict 91
# predict 5
# predict 17
# predict 78
# predict 69
# predict 31
# predict 53
# predict 85
# predict 37
# predict 99
# predict 60
# predict 32
# predict 36
# predict 33
# predict 51
# predict 52
# predict 6
# predict 34
# predict 1
# predict 10
# predict 32
# predict 36
# predict 89
# predict 61
# predict 39
# predict 12
# predict 45
# predict 44
# predict 8
# predict 63
# predict 57
# predict 97
# predict 94
# predict 53
# predict 25
# predict 44
# predict 52
# predict 11
# predict 95
# predict 50
# predict 19
# predict 11
# predict 62
# predict 40
# predict 7
# predict 8
# predict 80
# predict 13
# predict 1
# predict 4
# predict 52
# predict 16
# predict 68
# predict 82
# predict 60
# predict 67
# predict 16
# predict 62
# predict 65
# predict 20
# predict 45
# predict 88
# predict 62
# predict 22
# predict 1
# predict 64
# predict 95
# predict 85
# predict 2
# predict 85
# predict 61
# predict 77
# predict 23
# predict 15
# predict 25
# predict 47
# predict 33
# predict 81
# predict 71
# predict 55
# predict 25
# predict 78
# predict 90
# predict 36
# predict 58
# predict 32
# predict 40
# predict 15
# predict 94
# predict 49
# predict 14
# predict 20
# predict 16
# predict 98
# predict 42
# predict 36
# predict 26
# predict 52
# predict 35
# predict 23
# predict 34
# predict 100
# predict 62
# predict 79
# predict 8
# predict 33
# predict 4
# predict 68
# predict 96
# predict 58
# predict 97
# predict 47
# predict 90
# predict 22
# predict 93
# predict 100
# predict 85
# predict 59
# predict 65
# predict 41
# predict 79
# predict 79
# predict 63
# predict 63
# predict 48
# predict 28
# predict 72
# predict 43
# predict 15
# predict 94
# predict 52
# predict 19
# predict 79
# predict 11
# predict 36
# predict 50
# predict 94
# predict 80
# predict 90
# predict 5
# predict 6
# predict 87
# predict 30
# predict 54
# predict 81
# predict 73
# predict 30
# predict 39
# predict 79
# predict 55
# predict 43
# predict 65
# predict 69
# predict 45
# predict 85
# predict 74
# predict 51
# predict 81
# predict 51
# predict 36
# predict 73
# predict 16
# predict 40
# predict 3
# predict 36
# predict 98
# predict 80
# predict 16
# predict 16
# predict 95
# predict 67
# predict 35
# predict 84
# predict 94
# predict 19
# predict 75
# predict 19
# predict 26
# predict 18
# predict 50
# predict 38
# predict 21
# predict 41
# predict 53
# predict 24
# predict 19
# predict 80
# predict 52
# predict 33
# predict 38
# predict 31
# predict 41
# predict 51
# predict 74
# predict 69
# predict 81
# predict 16
# predict 64
# predict 65
# predict 92
# predict 21
# predict 55
# predict 24
# predict 7
# predict 25
# predict 1
# predict 49
# predict 81
# predict 29
# predict 89
# predict 2
# predict 74
# predict 22
# predict 1
# predict 77
# predict 33
# predict 41
# predict 82
# predict 84
# predict 31
# predict 88
# predict 54
# predict 34
# predict 83
# predict 23
# predict 4
# predict 35
# predict 50
# predict 89
# predict 71
# predict 38
# predict 34
# predict 13
# predict 38
# predict 80
# predict 66
# predict 7
# predict 80
# predict 93
# predict 4
# predict 33
# predict 86
# predict 45
# predict 30
# predict 47
# predict 68
# predict 67
# predict 29
# predict 58
# predict 85
# predict 44
# predict 95
# predict 94
# predict 21
# predict 53
# predict 32
# predict 26
# predict 64
# predict 53
# predict 60
# predict 18
# predict 23
# predict 55
# predict 14
# predict 31
# predict 24
# predict 51
# predict 22
# predict 72
# predict 4
# predict 24
# predict 13
# predict 78
# predict 8
# predict 53
# predict 31
# predict 27
# predict 9
# predict 97
# predict 85
# predict 82
# predict 74
# predict 40
# predict 57
# predict 61
# predict 26
# predict 66
# predict 96
# predict 100
# predict 28
# predict 19
# predict 87
# predict 2
# predict 35
# predict 3
# predict 18
# predict 86
# predict 12
# predict 94
# predict 54
# predict 60
# predict 83
# predict 12
# predict 84
# predict 4
# predict 84
# predict 1
# predict 94
# predict 86
# predict 52
# predict 92
# predict 33
# predict 87
# predict 85
# predict 100
# predict 82
# predict 6
# predict 12
# predict 70
# predict 10
# predict 47
# predict 75
# predict 94
# predict 33
# predict 39
# predict 43
# predict 64
# predict 24
# predict 41
# predict 64
# predict 64
# predict 32
# predict 19
# predict 41
# predict 6
# predict 93
# predict 80
# predict 83
# predict 75
# predict 41
# predict 26
# predict 69
# predict 50
# predict 83
# predict 87
# predict 47
# predict 14
# predict 22
# predict 81
# predict 82
# predict 95
# predict 50
# predict 52
# predict 15
# predict 31
# predict 11
# predict 86
# predict 5
# predict 8
# predict 55
# predict 60
# predict 85
# predict 99
# predict 42
# predict 36
# predict 57
# predict 14
# predict 12
# predict 53
# predict 67
# predict 22
# predict 82
# predict 95
# predict 35
# predict 62
# predict 92
# predict 86
# predict 61
# predict 100
# predict 93
# predict 99
# predict 92
# predict 75
# predict 9
# predict 76
# predict 82
# predict 28
# predict 26
# predict 87
# predict 37
# predict 15
# predict 4
# predict 93
# predict 85
# predict 73
# predict 44
# predict 100
# predict 9
# predict 56
# predict 18
# predict 61
# predict 33
# predict 99
# predict 84
# predict 28
# predict 96
# predict 53
# predict 51
# predict 81
# predict 92
# predict 80
# predict 27
# predict 38
# predict 25
# predict 57
# predict 41
# predict 53
# predict 39
# predict 20
# predict 45
# predict 21
# predict 64
# predict 22
# predict 66
# predict 69
# predict 93
# predict 19
# predict 69
# predict 17
# predict 79
# predict 60
# predict 57
# predict 45
# predict 36
# predict 40
# predict 62
# predict 33
# predict 68
# predict 54
# predict 63
# predict 76
# predict 9
# predict 35
# predict 34
# predict 93
# predict 26
# predict 68
# predict 2
# predict 99
# predict 9
# predict 90
# predict 28
# predict 30
# predict 90
# predict 78
# predict 11
# Ваш алгоритм угадывает число в среднем за 8 попыток
# 8
